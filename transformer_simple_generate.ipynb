# %%
import os
import random
import string

import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.python.keras.layers import TextVectorization

# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
M_VOCAB_SZ = 20000
M_MAX_LEN = 80
M_ATT_HEADS = 2
M_DIM_EMB = 256
M_DIM_FFN = 256
T_BATCH_SIZE = 256
T_EPOCHS = 1

data_files = ["data_test_wikitext/wiki.train.tokens"]

# %%
def causal_attention_mask(batch_size, n_dest, n_src, dtype):
    i = tf.range(n_dest)[:, None]
    j = tf.range(n_src)
    m = i >= j - n_src + n_dest
    mask = tf.cast(m, dtype)
    mask = tf.reshape(mask, [1, n_dest, n_src])
    mult = tf.concat([tf.expand_dims(batch_size, -1), tf.constant([1, 1], dtype=tf.int32)], 0)
    return tf.tile(mask, mult)


class Transformer(layers.Layer):
    def __init__(self, embedding_dim, num_att_heads, state_dims, dropout_rate=0.1):
        super(Transformer, self).__init__()
        self.embedding_dim = embedding_dim
        self.num_att_heads = num_att_heads
        self.state_dims = state_dims
        self.dropout_rate = dropout_rate
        self.attention = layers.MultiHeadAttention(num_att_heads, embedding_dim)
        self.feed_forward = keras.Sequential([
            layers.Dense(state_dims, activation="relu"),
            layers.Dense(embedding_dim)
        ])
        self.norm1, self.norm2 = layers.LayerNormalization(epsilon=1e-6), layers.LayerNormalization(epsilon=1e-6)
        self.drop1, self.drop2 = layers.Dropout(dropout_rate), layers.Dropout(dropout_rate)

    def call(self, inputs):
        inp_shape = tf.shape(inputs)
        batch_sz, seq_len = inp_shape[0], inp_shape[1]
        causal_mask = causal_attention_mask(batch_sz, seq_len, seq_len, tf.bool)
        attention_out = self.attention(inputs, inputs, attention_mask=causal_mask)
        attention_out = self.drop1(attention_out)
        out1 = self.norm1(inputs + attention_out)
        feed_forward_out = self.feed_forward(out1)
        feed_forward_out = self.drop2(feed_forward_out)
        return self.norm2(out1 + feed_forward_out)

    def get_config(self):
        config = super().get_config()
        config.update({
            "embedding_dim": self.embedding_dim,
            "num_att_heads": self.num_att_heads,
            "state_dims": self.state_dims,
            "dropout_rate": self.dropout_rate,
        })
        return config

class TokenAndPositionEmbedding(layers.Layer):
    def __init__(self, max_len, vocab_size, embed_dim):
        super(TokenAndPositionEmbedding, self).__init__()
        self.max_len = max_len
        self.vocab_size = vocab_size
        self.embed_dim = embed_dim
        self.token_emb = layers.Embedding(input_dim=vocab_size, output_dim=embed_dim)
        self.pos_emb = layers.Embedding(input_dim=max_len, output_dim=embed_dim)

    def call(self, x):
        max_len = tf.shape(x)[-1]
        pos = tf.range(start=0, limit=max_len, delta=1)
        pos = self.pos_emb(pos)
        x = self.token_emb(x)
        return x + pos

    def get_config(self):
        config = super().get_config()
        config.update({
            "max_len": self.max_len,
            "vocab_size": self.vocab_size,
            "embed_dim": self.embed_dim,
        })
        return config

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, embedding_dim, warmup_steps=4000):
        super(CustomSchedule, self).__init__()
        self.emb_dim = tf.cast(embedding_dim, tf.float32)
        self.warmup_steps = warmup_steps

    def __call__(self, step):
        step = tf.cast(step, tf.float32)
        arg1 = tf.math.rsqrt(step)
        arg2 = step * (self.warmup_steps ** -1.5)
        return tf.math.rsqrt(self.emb_dim) * tf.math.minimum(arg1, arg2)

    def get_config(self):
        config = super().get_config()
        config.update({
            "emb_dim": self.emb_dim,
            "warmup_steps": self.warmup_steps,
        })
        return config

# %%
def create_model():
    # TODO: Remove this if we're using tokenizer
    embedding = TokenAndPositionEmbedding(M_MAX_LEN, vocab_size, M_DIM_EMB)
    transformer = Transformer(M_DIM_EMB, M_ATT_HEADS, M_DIM_FFN)

    l_input = layers.Input(shape=(M_MAX_LEN,), dtype=tf.int32)
    l_emb = embedding(l_input)
    l_trans = transformer(l_emb)
    l_output = layers.Dense(vocab_size)(l_trans)

    m = keras.Model(inputs=l_input, outputs=[l_output, l_trans])
    loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
    learning_rate = CustomSchedule(M_DIM_EMB)
    optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98, epsilon=1e-9)

    m.compile(optimizer, loss=[loss_fn, None])
    return m

# %%
def create_dataset(file_pth, batch_sz, buf_sz=1000, shuffle=True):
    # Shuffle the data and create batches
    if shuffle:
        random.shuffle(file_pth)
    ds = tf.data.TextLineDataset(file_pth)
    ds = ds.shuffle(buffer_size=buf_sz)
    ds = ds.batch(batch_sz)
    return ds


def create_tokenizer(dataset, max_vocab_size):
    def preprocess_txt(input_string):
        # Preprocessing for word-level model
        s1 = tf.strings.lower(input_string)
        return tf.strings.regex_replace(s1, f"([{string.punctuation}])", r" \1")

    # Vectorization of the data
    vectorize = TextVectorization(
        standardize=preprocess_txt,
        max_tokens=vocab_size - 1,
        output_mode="int",
        output_sequence_length=M_MAX_LEN + 1,
    )
    vectorize.adapt(dataset)
    vocab = vectorize.get_vocabulary()
    return vectorize, vocab


# Read in the data and create the dataset
dataset = create_dataset(data_files, T_BATCH_SIZE)
# Create the tokenizer
tokenizer, vocab = create_tokenizer(dataset, M_VOCAB_SZ)


def create_sequences(txt):
    txt = tf.expand_dims(txt, -1)
    txt_tok = tokenizer(txt)
    return txt_tok[:, :-1], txt_tok[:, 1:]


dataset = dataset.map(create_sequences).prefetch(tf.data.AUTOTUNE)

# %%
for d in dataset.take(1):
    print(d)
# Out:
# (<tf.Tensor: shape=(256, 80), dtype=int64, numpy=
# array([[   13,   225,  3108, ...,     0,     0,     0],
#        [11490,  3970,    30, ...,     2,   829,   813],
#        [    0,     0,     0, ...,     0,     0,     0],
#        ...,
#        [    2,  1318,  8359, ...,     0,     0,     0],
#        [   63,  7488,   140, ...,  7488,     7,     6],
#        [    5,    38,   123, ...,    32,  1204,     7]])>, <tf.Tensor: shape=(256, 80), dtype=int64, numpy=
# array([[ 225, 3108,   10, ...,    0,    0,    0],
#        [3970,   30,    1, ...,  829,  813, 9256],
#        [   0,    0,    0, ...,    0,    0,    0],
#        ...,
#        [1318, 8359, 8688, ...,    0,    0,    0],
#        [7488,  140,  142, ...,    7,    6, 7707],
#        [  38,  123,    3, ..., 1204,    7,    6]])>)

# %%
class TextGenerator(keras.callbacks.Callback):
    def __init__(self, max_tokens, start_tokens, index_to_word, top_k=10, print_every=1):
        self.max_tokens = max_tokens
        self.start_tokens = start_tokens
        self.index_to_word = index_to_word
        self.print_every = print_every
        self.k = top_k

    def sample_from(self, logits):
        logits, indices = tf.math.top_k(logits, k=self.k, sorted=True)
        indices = np.asarray(indices).astype("int32")
        preds = keras.activations.softmax(tf.expand_dims(logits, 0))[0]
        preds = np.asarray(preds).astype("float32")
        return np.random.choice(indices, p=preds)

    def detokenize(self, number):
        return self.index_to_word[number]

    def on_epoch_end(self, epoch, logs=None):
        start_tokens = list(self.start_tokens)
        if (epoch + 1) % self.print_every != 0:
            return
        num_tokens_generated = 0
        tokens_generated = []
        while num_tokens_generated <= self.max_tokens:
            pad_len = M_MAX_LEN - len(start_tokens)
            sample_index = len(start_tokens) - 1
            if pad_len < 0:
                x = start_tokens[:M_MAX_LEN]
                sample_index = M_MAX_LEN - 1
            elif pad_len > 0:
                x = start_tokens + [0] * pad_len
            else:
                x = start_tokens
            x = np.array([x])
            y, _ = self.model.predict(x)
            sample_token = self.sample_from(y[0][sample_index])
            tokens_generated.append(sample_token)
            start_tokens.append(sample_token)
            num_tokens_generated = len(tokens_generated)
        txt = " ".join([self.detokenize(_) for _ in self.start_tokens + tokens_generated])
        print(f"Generated:\n{txt}\n")

# %%
def create_generation_callback(start_prompt, vocabulary, gen_len=100):
    # Tokenize starting prompt
    word_to_index = {word: index for index, word in enumerate(vocabulary)}
    prompt_tokens = [word_to_index.get(_, 1) for _ in start_prompt.lower().split()]
    return TextGenerator(gen_len, prompt_tokens, vocabulary)

def create_callbacks(base_dir, model, defaults: list = None):
    import tensorflow as tf
    print(f'base_dir: {base_dir}')
    dir_models = os.path.join(base_dir, model.name)
    path_csv = os.path.join(dir_models, 'history.csv')
    print("History CSV:", path_csv)
    path_ckp = os.path.join(dir_models, 'checkpoints.h5')
    print("Checkpoint:", path_ckp)
    path_tb = os.path.join(dir_models, "logs")
    tb_file_writer = tf.summary.create_file_writer(path_tb)
    callbacks = [] if defaults is None else defaults
    callbacks.append(tf.keras.callbacks.TensorBoard(log_dir=path_tb, histogram_freq=1))
    callbacks.append(tf.keras.callbacks.CSVLogger(path_csv, separator=",", append=True))
    # callbacks.append(tf.keras.callbacks.ModelCheckpoint(path_ckp,
    #                                                     monitor='loss',
    #                                                     save_best_only=True,
    #                                                     mode='auto',
    #                                                     verbose=0))
    os.makedirs(dir_models, exist_ok=True)
    return callbacks, tb_file_writer

# %%
# Clear any logs from previous runs
# !rm -rf ./logs/

# %%
os.makedirs("./logs", exist_ok=True)
# %tensorboard --logdir logs/

# %%
model = create_model()
callbacks, tb_file_writer = create_callbacks("logs", model)
gen_callback = create_generation_callback("a day in the life", vocab)
callbacks.append(gen_callback)
# Out:
# base_dir: logs
# History CSV: logs/model_2/history.csv
# Checkpoint: logs/model_2/checkpoints.h5

# %%
# wandb.tensorboard.patch(root_logdir="logs")
# wandb.init(project='transformer')
model.fit(dataset, verbose=2, epochs=T_EPOCHS, callbacks=callbacks)
# Out:
# Epoch 1/30
# Generated:
# a day in the life since been longer he day  this  and island june  to was but and records as area between  there red be  their this   there from included but he described but be most with he  he also . area    in the day   but was  while  he there to   be  .    he he  . on day with  be day area central be day  be was with   be be was   area    area with to
#
# 144/144 - 25s - loss: 9.2713 - dense_8_loss: 9.2713 - 25s/epoch - 171ms/step
# Epoch 2/30
# Generated:
# a day in the life  to [UNK]  and " [UNK] the [UNK]  , .  in .    . ,    <unk <unk  . to in    . and   in to  [UNK]   [UNK]  . to  in ,   and <unk   the , to . . . and  [UNK] <unk was and    the  <unk in @ in     .  @ <unk  and the ,   to and in   , <unk . <unk .
#
# 144/144 - 25s - loss: 6.6075 - dense_8_loss: 6.6075 - 25s/epoch - 174ms/step
# Epoch 3/30
# Generated:
# a day in the life         =                          =                                                     .        .   the
#
# 144/144 - 25s - loss: 3.7419 - dense_8_loss: 3.7419 - 25s/epoch - 172ms/step
# Epoch 4/30
# Generated:
# a day in the life <unk > and [UNK] <unk > , and a <unk > to the first of his <unk > in the . a of the same <unk > in , [UNK] , the . the united the <unk > . the <unk > and [UNK] . in the <unk > and the <unk > and <unk > of the . the first <unk > , the <unk > of a of the , , a [UNK] in of to in of of , . , of of , of and . , of , <unk to and , , and <unk (
#
# 144/144 - 25s - loss: 2.6780 - dense_8_loss: 2.6780 - 25s/epoch - 172ms/step
# Epoch 5/30
# Generated:
# a day in the life of the first " , a [UNK] ) and [UNK] ) was that the <unk > .
#
# 144/144 - 25s - loss: 2.4217 - dense_8_loss: 2.4217 - 25s/epoch - 174ms/step
# Epoch 6/30
# Generated:
# a day in the life , a few and [UNK] ) , <unk > ( [UNK] and the <unk > of this 's first <unk > [UNK] ) in the game 's <unk > , and [UNK] ( [UNK] and <unk > <unk > of [UNK] <unk > ( [UNK] and the episode of <unk > <unk > in his <unk > ( <unk > ) , @ - @ - @ - @ - @ 000 to " . " @ @  <unk it the    @ @ the in  the  "  <unk the  the <unk the <unk
#
# 144/144 - 25s - loss: 2.2937 - dense_8_loss: 2.2937 - 25s/epoch - 171ms/step
# Epoch 7/30
# Generated:
# a day in the life , the <unk > <unk > <unk > of <unk > <unk > . <unk > and <unk > <unk > <unk > <unk > " ( <unk > " ) , the first : <unk > ) is the <unk > <unk > , <unk > ) .
#
# 144/144 - 24s - loss: 2.2106 - dense_8_loss: 2.2106 - 24s/epoch - 164ms/step
# Epoch 8/30
# Generated:
# a day in the life of the <unk > in the episode of <unk > and the <unk > <unk > . <unk > and was also known as an [UNK] . [UNK] <unk > . the <unk > and a <unk > , and [UNK] . the early as a [UNK] ( [UNK] ) and <unk > . <unk > ) , but is a series of <unk > [UNK] , is a few <unk > of <unk > and @ and , ( <unk and ( , <unk , [UNK] , , <unk [UNK] . and , , and , <unk @ ( <unk
#
# 144/144 - 22s - loss: 2.1443 - dense_8_loss: 2.1443 - 22s/epoch - 155ms/step
# Epoch 9/30
# Generated:
# a day in the life is known as a <unk > @ - @ [UNK] @ .
#
# 144/144 - 23s - loss: 2.0829 - dense_8_loss: 2.0829 - 23s/epoch - 157ms/step
# Epoch 10/30
# Generated:
# a day in the life of the first two of the [UNK] and has been used as of their <unk > and other hand in the <unk > in the <unk > <unk > and [UNK] , the <unk > ( [UNK] ) is a [UNK] ( <unk > <unk > ) , <unk > [UNK] [UNK] . [UNK] <unk > , as the <unk > . the [UNK] [UNK] <unk > [UNK] has a [UNK] [UNK] <unk > <unk > > > > > > > > > > > > > > > > > > > > > > > > > >
#
# 144/144 - 22s - loss: 2.0215 - dense_8_loss: 2.0215 - 22s/epoch - 155ms/step
# Epoch 11/30
# Generated:
# a day in the life of his death in a [UNK] . in the episode was a number of a number of the [UNK] , which is not known for the [UNK] and <unk > . this is <unk > <unk > <unk > and <unk > , is a <unk > [UNK] <unk > <unk > , <unk > . <unk > [UNK] <unk > @ - @ [UNK] <unk > <unk > , which is also used by [UNK] a a <unk a [UNK] the <unk the this [UNK] <unk the the some this the a the <unk an <unk <unk some <unk the
#
# 144/144 - 22s - loss: 1.9608 - dense_8_loss: 1.9608 - 22s/epoch - 156ms/step
# Epoch 12/30
# Generated:
# a day in the life of the <unk > of the [UNK] ( [UNK] ) . the <unk > is an <unk > , the genus [UNK] [UNK] <unk > of <unk > of the <unk > of <unk > and has no <unk > . the [UNK] in the [UNK] [UNK] , <unk > <unk > <unk > <unk > , <unk > <unk > <unk > <unk > ( <unk > ) , <unk > , <unk > <unk , ( <unk . ( , ( ( <unk ; <unk and , , <unk <unk , [UNK] [UNK] and <unk ( of ( and
#
# 144/144 - 22s - loss: 1.9023 - dense_8_loss: 1.9023 - 22s/epoch - 156ms/step
# Epoch 13/30
# Generated:
# a day in the life , the film of the song dynasty and was one of the second single of the game , and released on the game 's first world 's release of all three games and number of the game 's " .
#
# 144/144 - 23s - loss: 1.8461 - dense_8_loss: 1.8461 - 23s/epoch - 160ms/step
# Epoch 14/30
# Generated:
# a day in the life of the [UNK] @ - @ century <unk > of the [UNK] ( <unk > ) , which was the first of a <unk > of the <unk > @ - @ day @ - @ time .
#
# 144/144 - 25s - loss: 1.7924 - dense_8_loss: 1.7924 - 25s/epoch - 175ms/step
# Epoch 15/30
# Generated:
# a day in the life is based on earth .
#
# 144/144 - 24s - loss: 1.7400 - dense_8_loss: 1.7400 - 24s/epoch - 169ms/step
# Epoch 16/30
# Generated:
# a day in the life cycle of the same year , as a study of the <unk > <unk > <unk > , a <unk > <unk > , which can have a large <unk > <unk > @ - @ like a <unk > <unk > " star <unk > <unk > .
#
# 144/144 - 24s - loss: 1.6888 - dense_8_loss: 1.6888 - 24s/epoch - 166ms/step
# Epoch 17/30
# Generated:
# a day in the life of his father 's father of his wife , king , died at a [UNK] , and she was a member of his <unk > in his wife when it was [UNK] [UNK] . she was buried in the only child to the same time in a [UNK] . when he <unk > [UNK] is a friend of his wife , the [UNK] , who are [UNK] , is able to help to [UNK] . he   the his  his      his the they he his  meanwhile    the  <unk they
#
# 144/144 - 24s - loss: 1.6392 - dense_8_loss: 1.6392 - 24s/epoch - 166ms/step
# Epoch 18/30
# Generated:
# a day in the life of the process of mass stars have a mass @ - @ rate of stars – 3 . @ 4 % . the rate of the stars , 1 @ 4 % of 10 % ( 5 @ . @ 2 % ) , @ , @ 000 cu ft ) is a star , and is a length of the highest total <unk > @ - @ based on the star 's population of these [UNK] the <unk 1 the <unk the the water [UNK] water <unk the stars these the the the all [UNK] star a the the stars
#
# 144/144 - 23s - loss: 1.5914 - dense_8_loss: 1.5914 - 23s/epoch - 161ms/step
# Epoch 19/30
# Generated:
# a day in the life of a group of the [UNK] . <unk > <unk > ( [UNK] ) <unk > – <unk > . ( <unk > ) , [UNK] ( <unk > ) ; only the [UNK] ( born <unk > ; <unk > ) in the <unk > are <unk > <unk > , <unk > and <unk > .
#
# 144/144 - 25s - loss: 1.5445 - dense_8_loss: 1.5445 - 25s/epoch - 176ms/step
# Epoch 20/30
# Generated:
# a day in the life of his appearance of [UNK] and [UNK] , the [UNK] ( [UNK] ) , is the most important than the <unk > and other <unk > <unk > <unk > of these <unk > . it contains eight [UNK] [UNK] , and [UNK] [UNK] and <unk > ( <unk > , ) <unk > ( [UNK] ) , <unk > of <unk > , as <unk > , <unk > , [UNK] , <unk > , , and , , and and , , <unk , , ( , ( , and or <unk , ( <unk [UNK] , , (
#
# 144/144 - 23s - loss: 1.4988 - dense_8_loss: 1.4988 - 23s/epoch - 160ms/step
# Epoch 21/30
# Generated:
# a day in the life of the labyrinth of urania is the novel written with bolívar 's novel by her book . the novel includes a piano , [UNK] of <unk > and dorothy barker , in his friend and his son . his father 's father and her friend [UNK] , he wrote a romantic movement of his life . he described his son , he was a romantic novel about his friend of his son and the son 's of of of and 's of 's and of and he of of of of of 's of of of , of , of of
#
# 144/144 - 23s - loss: 1.4544 - dense_8_loss: 1.4544 - 23s/epoch - 159ms/step
# Epoch 22/30
# Generated:
# a day in the life of the age of alkan 's life was so much more than i . . . . . . . . in a . . . . . . . . . . . . . . . . . . . . . . . for m . . . the . . m . 13 m . m @ 4 m ☉ , the m @ - @ 44 is in the star is begins spends clusters can @ sirius is is begins begins of @ sirius sirius can sirius sirius 's is is 's sirius @ spends clusters
#
# 144/144 - 23s - loss: 1.4110 - dense_8_loss: 1.4110 - 23s/epoch - 160ms/step
# Epoch 23/30
# Generated:
# a day in the life of walpole 's death of his death in his life , in his career . he was married , and she was born in the last three days . she also had a family and her mother of the painter [UNK] , but his wife and family . he was married , but she was born at her children aged 16 years . she attended and was attended in [UNK] bc and was born in his early early 1824 <unk the [UNK] the germany 1939 1939 [UNK] 1914 [UNK] <unk 1824 germany the <unk <unk <unk [UNK] <unk 1824 1605 early
#
# 144/144 - 23s - loss: 1.3687 - dense_8_loss: 1.3687 - 23s/epoch - 158ms/step
# Epoch 24/30
# Generated:
# a day in the life of alkan 's child 's death in the family was one and often confused with his work of alkan 's <unk > .
#
# 144/144 - 23s - loss: 1.3270 - dense_8_loss: 1.3270 - 23s/epoch - 159ms/step
# Epoch 25/30
# Generated:
# a day in the life of study and that it was found a wide variety of <unk > . as the result in the illustration and approached by [UNK] ( [UNK] ) and the later productions after the early 1980s , the museum of the observatory had been used for organ for the building . the museum has been rebuilt and paintings produced by a large wooden beams in the <unk > . the stone echoed busch 's resemblance to the overcrowding the the buddhism the the the buddhism the <unk the their <unk the the her the the her <unk the the the the the
#
# 144/144 - 23s - loss: 1.2876 - dense_8_loss: 1.2876 - 23s/epoch - 158ms/step
# Epoch 26/30
# Generated:
# a day in the life of alkan 's music concert at <unk > , <unk > , and <unk > <unk > , [UNK] wrote to be [UNK] in detail in 1962 to his style circles took over to live and from their own arrangements . . however , the conservatoire de paris edition ( organ ) , a contemporary [UNK] of the music , the pseudonym of whom he had been credited for his career in 1924 , and charm his uruguay clark brother brother brother he his charm brother brother his virtuoso brother his brother uruguay his his clark his his his his his
#
# 144/144 - 24s - loss: 1.2495 - dense_8_loss: 1.2495 - 24s/epoch - 163ms/step
# Epoch 27/30
# Generated:
# a day in the life of alkan 's music teacher at the conservatoire in paris , alkan society ( piano ) , 2005 and paris at his career spanning more [UNK] in 1952 . he was the conservatoire piano ) and <unk > ( piano ) and paintings since 1916 .
#
# 144/144 - 26s - loss: 1.2115 - dense_8_loss: 1.2115 - 26s/epoch - 180ms/step
# Epoch 28/30
# Generated:
# a day in the life of walpole , but he was his most of his career and his works better than that he was his works of cancer . he received an honorary degree in 2002 study and published a biography by gabriel . he was a standout " in 1986 and a piano ballad piano . it is the <unk > <unk > of the golden age of etty 's paintings , whose occasional elaborate funeral in the descriptions were of of and and of of of of were in of of of of of of were of of of of of of of of
#
# 144/144 - 24s - loss: 1.1769 - dense_8_loss: 1.1769 - 24s/epoch - 165ms/step
# Epoch 29/30
# Generated:
# a day in the life of the armed shiva worshipped as the hindu temples near the [UNK] . the sidonian core of <unk > , commemorate the <unk > , was transferred to the court to the <unk > of the <unk > . on the eshmun temple was a roman <unk > in the <unk > , which [UNK] castle and the temple site <unk > " ydll " spring ; in the <unk > roman <unk > , originates the the it the it is originates the he originates <unk <unk the the was the the the the the the the originates the the
#
# 144/144 - 24s - loss: 1.1385 - dense_8_loss: 1.1385 - 24s/epoch - 164ms/step
# Epoch 30/30
# Generated:
# a day in the life of a star can be called the sun at its heat transfer , and <unk > , radius , or about 0 @ . @ 5 times midge with 1 @ . @ 5 times even as they are being <unk > for a hard disk for which , but can meet making it an insect vector . a 2 @ .
#
# 144/144 - 25s - loss: 1.0993 - dense_8_loss: 1.0993 - 25s/epoch - 176ms/step

# %%
model.save("model_warmup.h5")
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /tmp/ipykernel_293987/2003129594.py in <module>
# ----> 1 model.save("model_warmup.h5")
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /tmp/ipykernel_293987/1815149928.py in get_config(self)
#      12
#      13     def get_config(self):
# ---> 14         config = super().get_config()
#      15         config.update({
#      16             "emb_dim": self.emb_dim,
#
# NotImplementedError: Learning rate schedule must override get_config
