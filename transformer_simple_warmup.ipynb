# %%
#@formatter:off
# %load_ext autoreload
# %autoreload 2
#@formatter:on
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.Config import Config
from src.SimpleTransformerLMHead import SimpleTransformerLMHead

# %%
config = Config(
    {
        "VOCAB_SZ": 3000,
        "MAX_LEN": 100,
        "ATT_HEADS": 2,
        "DIM_EMB": 100,
        "DIM_FFN": 2048,
        "WARMUP_STEPS": 10000,
    },
    {
        "BATCH_SIZE": 256,
        "EPOCHS": 10,
        "DATASET": ["data/beatles.txt"]
    })
# "DATASET": ["data/wiki2.train.tokens"]
# "DATASET": ["data/wiki2.train.raw"]
# "DATASET": ["data/beatles.txt"]

# %%
lm_model = SimpleTransformerLMHead().new(config)
# Out:
# # [SimpleTransformerLMHead] Initializing...
# # [SimpleTransformerLMHead] Creating new model...
# [DATASET]: Loading ['data/beatles.txt']
# [TOKENIZER]: Initializing...
# # [SimpleTransformerLMHead] Vocabulary size: 3580
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_2 (InputLayer)        [(None, 100)]             0
#
#  simple_transformer_2 (Simpl  ((None, 100, 5000),      1507848
#  eTransformer)                (None, 100, 100))
#
# ...
# Total params: 1,507,848
# Trainable params: 1,507,848
# Non-trainable params: 0
# _________________________________________________________________

# %%
prompt = "I'm sorry, Dave. I'm afraid I can't do that."

# %%
lm_model.train(prompt)
# Out:
# # [SimpleTransformerLMHead] Training...
# # Model Dir: logs/model_1
#  - History Path: logs/model_1/history.csv
#  - Checkpoint Path: logs/model_1/checkpoints.h5
#  - TB Path: logs/model_1
# Epoch 1/10
#      20/Unknown - 2s 63ms/step - loss: 8.5813 - simple_transformer_2_loss: 8.5813Generated 101 tokens
#
# # GREEDY GENERATED:
# ...

# %%
lm_model.save()

# %%
generated_txt = lm_model.generate(prompt, 200)
print(generated_txt)

# %%
load_lm_model = SimpleTransformerLMHead().load("model_save")

# %%
load_lm_model.generate(prompt, 200)
