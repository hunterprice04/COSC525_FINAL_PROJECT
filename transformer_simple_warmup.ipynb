# %%
#@formatter:off
# %load_ext autoreload
# %autoreload 2
#@formatter:on
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import random
import string

import tensorflow as tf
from src.Generation import GenerationCallback, Generator
from src.Model import TokenAndPositionEmbedding
from src.Model import Transformer
from src.Model import WarmupScheduler
from src import Utils
from src.Configs import ModelConfig
from src.Configs import TrainingConfig
import pickle

# %%
def create_model(model_config: ModelConfig):
    # TODO: Remove this if we're using tokenizer
    embedding = TokenAndPositionEmbedding(model_config.M_MAX_LEN, model_config.M_VOCAB_SZ, model_config.M_DIM_EMB)
    transformer = Transformer(model_config.M_DIM_EMB, model_config.M_ATT_HEADS, model_config.M_DIM_FFN)

    l_input = tf.keras.layers.Input(shape=(model_config.M_MAX_LEN,), dtype=tf.int32)
    l_emb = embedding(l_input)
    l_trans = transformer(l_emb)
    l_output = tf.keras.layers.Dense(model_config.M_VOCAB_SZ)(l_trans)

    m = tf.keras.Model(inputs=l_input, outputs=[l_output, l_trans])
    loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
    learning_rate = WarmupScheduler(model_config.M_DIM_EMB, model_config.M_WARMUP_STEPS)
    optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98, epsilon=1e-9)

    m.compile("adam", loss=[loss_fn, None])
    return m

# %%
def create_dataset(file_pth, batch_sz, buf_sz=1000, shuffle=True):
    # Shuffle the data and create batches
    if shuffle:
        random.shuffle(file_pth)
    ds = tf.data.TextLineDataset(file_pth)
    ds = ds.shuffle(buffer_size=buf_sz)
    ds = ds.batch(batch_sz)
    return ds


def create_tokenizer(dataset, max_vocab_size, max_seq_len):
    def preprocess_txt(input_string):
        # Preprocessing for word-level model
        s1 = tf.strings.lower(input_string)
        return tf.strings.regex_replace(s1, f"([{string.punctuation}])", r" \1")

    # Vectorization of the data
    vectorize = tf.keras.layers.TextVectorization(
        standardize=preprocess_txt,
        max_tokens=max_vocab_size - 1,
        output_mode="int",
        output_sequence_length=max_seq_len + 1,
    )
    vectorize.adapt(dataset)
    vocab = vectorize.get_vocabulary()
    return vectorize, vocab


config_model, config_training = ModelConfig(), TrainingConfig()
# Read in the data and create the dataset
dataset = create_dataset(config_training.T_DATASET, config_training.T_BATCH_SIZE)
# Create the tokenizer
tokenizer, vocab = create_tokenizer(dataset, config_model.M_VOCAB_SZ, config_model.M_MAX_LEN)

# %%
for d in dataset.take(1):
    print("=" * 80)
    print(d[0])
    print("=" * 80)
    print(d[1])
# Out:
# ================================================================================
# tf.Tensor(b'So many women wanna call me baby', shape=(), dtype=string)
# ================================================================================
# tf.Tensor(b'Why you gotta do me like that?', shape=(), dtype=string)

# %%
def create_sequences(txt):
    txt = tf.expand_dims(txt, -1)
    txt_tok = tokenizer(txt)
    return txt_tok[:, :-1], txt_tok[:, 1:]


dataset = dataset.map(create_sequences).prefetch(tf.data.AUTOTUNE)

# %%
for d in dataset.take(1):
    print("=" * 80)
    print(d[0])
    print("=" * 80)
    print(d[1])
# Out:
# ================================================================================
# tf.Tensor(
# [[   71    98    40 ...     0     0     0]
#  [ 9408  3205     2 ...     0     0     0]
#  [   33     9    83 ...     0     0     0]
#  ...
#  [  949    51   187 ...     0     0     0]
#  [   52   147  8454 ...     0     0     0]
#  [  379 19253  1158 ...     0     0     0]], shape=(256, 100), dtype=int64)
# ================================================================================
# tf.Tensor(
# [[   98    40     3 ...     0     0     0]
#  [ 3205     2 10521 ...     0     0     0]
#  [    9    83     3 ...     0     0     0]
#  ...
#  [   51   187  5640 ...     0     0     0]
#  [  147  8454  2491 ...     0     0     0]
#  [19253  1158  4869 ...     0     0     0]], shape=(256, 100), dtype=int64)

# %%
model = create_model(config_model)
callbacks, tb_file_writer = Utils.create_callbacks("logs", model)
gen_callback = GenerationCallback("i will always be", 100, config_model.M_MAX_LEN, vocab)
callbacks.append(gen_callback)
# Out:
# # Model Dir: logs/model_7
#  - History Path: logs/model_7/history.csv
#  - Checkpoint Path: logs/model_7/checkpoints.h5
#  - TB Path: logs/model_7

# %%
model.summary()
# Out:
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 100)]             0
#
#  token_and_position_embeddin  (None, 100, 128)         2572800
#  g_7 (TokenAndPositionEmbedd
#  ing)
#
#  transformer_7 (Transformer)  (None, 100, 128)         264192
#
#  dense_23 (Dense)            (None, 100, 20000)        2580000
#
# =================================================================
# Total params: 5,416,992
# Trainable params: 5,416,992
# Non-trainable params: 0
# _________________________________________________________________

# %%
# wandb.tensorboard.patch(root_logdir="logs")
# wandb.init(project='transformer')
model.fit(dataset, verbose=1, epochs=config_training.T_EPOCHS, callbacks=callbacks)
# Out:
# Epoch 1/20
#     675/Unknown - 86s 126ms/step - loss: 0.7827 - dense_23_loss: 0.7827
# Generated:
# i will always be
# 676/676 [==============================] - 90s 132ms/step - loss: 0.7826 - dense_23_loss: 0.7826
# Epoch 2/20
# 675/676 [============================>.] - ETA: 0s - loss: 0.4473 - dense_23_loss: 0.4473
# Generated:
# i will always be
# 676/676 [==============================] - 89s 132ms/step - loss: 0.4473 - dense_23_loss: 0.4473
# Epoch 3/20
# 675/676 [============================>.] - ETA: 0s - loss: 0.4213 - dense_23_loss: 0.4213
# Generated:
# i will always be
# 676/676 [==============================] - 90s 133ms/step - loss: 0.4213 - dense_23_loss: 0.4213
# Epoch 4/20
# 675/676 [============================>.] - ETA: 0s - loss: 0.4024 - dense_23_loss: 0.4024
# Generated:
# i will always be
# 676/676 [==============================] - 87s 129ms/step - loss: 0.4024 - dense_23_loss: 0.4024
# Epoch 5/20
# 675/676 [============================>.] - ETA: 0s - loss: 0.3872 - dense_23_loss: 0.3872
# Generated:
# i will always be
# 676/676 [==============================] - 88s 130ms/step - loss: 0.3872 - dense_23_loss: 0.3872
# Epoch 6/20
# 675/676 [============================>.] - ETA: 0s - loss: 0.3745 - dense_23_loss: 0.3745
# Generated:
# i will always be
# 676/676 [==============================] - 87s 129ms/step - loss: 0.3745 - dense_23_loss: 0.3745
# Epoch 7/20
# 675/676 [============================>.] - ETA: 0s - loss: 0.3637 - dense_23_loss: 0.3637
# Generated:
# i will always be
# 676/676 [==============================] - 87s 129ms/step - loss: 0.3637 - dense_23_loss: 0.3637
# Epoch 8/20
# 675/676 [============================>.] - ETA: 0s - loss: 0.3542 - dense_23_loss: 0.3542
# Generated:
# i will always be
# 676/676 [==============================] - 88s 130ms/step - loss: 0.3542 - dense_23_loss: 0.3542
# Epoch 9/20
# 675/676 [============================>.] - ETA: 0s - loss: 0.3459 - dense_23_loss: 0.3459
# Generated:
# i will always be
# 676/676 [==============================] - 88s 130ms/step - loss: 0.3459 - dense_23_loss: 0.3459
# Epoch 10/20
# 675/676 [============================>.] - ETA: 0s - loss: 0.3387 - dense_23_loss: 0.3387
# Generated:
# i will always be
# 676/676 [==============================] - 88s 130ms/step - loss: 0.3387 - dense_23_loss: 0.3387
# Epoch 11/20
# 675/676 [============================>.] - ETA: 0s - loss: 0.3325 - dense_23_loss: 0.3325
# Generated:
# i will always be
# 676/676 [==============================] - 88s 130ms/step - loss: 0.3325 - dense_23_loss: 0.3325
# Epoch 12/20
# 675/676 [============================>.] - ETA: 0s - loss: 0.3271 - dense_23_loss: 0.3271
# Generated:
# i will always be
# 676/676 [==============================] - 90s 133ms/step - loss: 0.3271 - dense_23_loss: 0.3271
# Epoch 13/20
# 589/676 [=========================>....] - ETA: 11s - loss: 0.3288 - dense_23_loss: 0.3288
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_759422/2856265576.py in <module>
#       1 # wandb.tensorboard.patch(root_logdir="logs")
#       2 # wandb.init(project='transformer')
# ----> 3 model.fit(dataset, verbose=1, epochs=config_training.T_EPOCHS, callbacks=callbacks)
#
# ~/.local/lib/python3.8/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/.local/lib/python3.8/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1412               logs = tmp_logs  # No error, now safe to assign to logs.
#    1413               end_step = step + data_handler.step_increment
# -> 1414               callbacks.on_train_batch_end(end_step, logs)
#    1415               if self.stop_training:
#    1416                 break
#
# ~/.local/lib/python3.8/site-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     436     """
#     437     if self._should_call_train_batch_hooks:
# --> 438       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     439
#     440   def on_test_batch_begin(self, batch, logs=None):
#
# ~/.local/lib/python3.8/site-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     295       self._call_batch_begin_hook(mode, batch, logs)
#     296     elif hook == 'end':
# --> 297       self._call_batch_end_hook(mode, batch, logs)
#     298     else:
#     299       raise ValueError(
#
# ~/.local/lib/python3.8/site-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     316       self._batch_times.append(batch_time)
#     317
# --> 318     self._call_batch_hook_helper(hook_name, batch, logs)
#     319
#     320     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# ~/.local/lib/python3.8/site-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     354     for callback in self.callbacks:
#     355       hook = getattr(callback, hook_name)
# --> 356       hook(batch, logs)
#     357
#     358     if self._check_timing:
#
# ~/.local/lib/python3.8/site-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1032
#    1033   def on_train_batch_end(self, batch, logs=None):
# -> 1034     self._batch_update_progbar(batch, logs)
#    1035
#    1036   def on_test_batch_end(self, batch, logs=None):
#
# ~/.local/lib/python3.8/site-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1104     if self.verbose == 1:
#    1105       # Only block async when verbose = 1.
# -> 1106       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1107       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1108
#
# ~/.local/lib/python3.8/site-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     605     return t.item() if np.ndim(t) == 0 else t
#     606
# --> 607   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     608
#     609
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     914
#     915   return pack_sequence_as(
# --> 916       structure[0], [func(*x) for x in entries],
#     917       expand_composites=expand_composites)
#     918
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     914
#     915   return pack_sequence_as(
# --> 916       structure[0], [func(*x) for x in entries],
#     917       expand_composites=expand_composites)
#     918
#
# ~/.local/lib/python3.8/site-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     599     # Don't turn ragged or sparse tensors to NumPy.
#     600     if isinstance(t, tf.Tensor):
# --> 601       t = t.numpy()
#     602     # Strings, ragged and sparse tensors don't have .item(). Return them as-is.
#     603     if not isinstance(t, (np.ndarray, np.generic)):
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1157     """
#    1158     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1159     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1160     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1161
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1123   def _numpy(self):
#    1124     try:
# -> 1125       return self._numpy_internal()
#    1126     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1127       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
model.save("model_save")
with open("model_save/vocab.pkl", "wb") as f:
    pickle.dump(vocab, f)
with open("model_save/config_model.pkl", "wb") as f:
    pickle.dump(config_model, f)
with open("model_save/config_training.pkl", "wb") as f:
    pickle.dump(config_training, f)
# Out:
# WARNING:absl:Found untraced functions such as embedding_14_layer_call_fn, embedding_14_layer_call_and_return_conditional_losses, embedding_15_layer_call_fn, embedding_15_layer_call_and_return_conditional_losses, multi_head_attention_7_layer_call_fn while saving (showing 5 of 26). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model_save/assets
# INFO:tensorflow:Assets written to: model_save/assets

# %%
# model.save("model_warmup.h5")
generator = Generator(model, config_model.M_MAX_LEN, vocab)
generated_txt = generator.generate("i will always be", 50)
print(generated_txt)
# Out:
# Generated 51 tokens
# i will always be where my niggaz at ?                                               where my niggaz at ?
