# %%
#@formatter:off
# %load_ext autoreload
# %autoreload 2
#@formatter:on
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.Config import Config
from src.SimpleTransformerLMHead import SimpleTransformerLMHead
# Out:
# /home/acozma/.local/lib/python3.8/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.6.0 and strictly below 2.9.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.9.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
# def create_model(model_config: ModelConfig):
#     # TODO: Remove this if we're using tokenizer
#     embedding = TokenAndPositionEmbedding(model_config.M_MAX_LEN, model_config.M_VOCAB_SZ, model_config.DIM_EMB)
#     transformer = Transformer(model_config.DIM_EMB, model_config.ATT_HEADS, model_config.DIM_FFN)
#
#     l_input = tf.keras.layers.Input(shape=(model_config.M_MAX_LEN,), dtype=tf.int32)
#     l_emb = embedding(l_input)
#     l_trans = transformer(l_emb)
#     l_output = tf.keras.layers.Dense(model_config.M_VOCAB_SZ)(l_trans)
#
#     m = tf.keras.Model(inputs=l_input, outputs=[l_output, l_trans])
#     loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
#     learning_rate = WarmupScheduler(model_config.DIM_EMB, model_config.WARMUP_STEPS)
#     optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98, epsilon=1e-9)
#
#     m.compile("adam", loss=[loss_fn, None])
#     return m

# %%
config = Config(
    {
        "VOCAB_SZ": 20000,
        "MAX_LEN": 100,
        "ATT_HEADS": 2,
        "DIM_EMB": 128,
        "DIM_FFN": 512,
        "WARMUP_STEPS": 2000,
    },
    {
        "BATCH_SIZE": 256,
        "EPOCHS": 20,
        "DATASET": ["data/beatles.txt"]
    })

# %%
lm_model = SimpleTransformerLMHead(config)
# Out:
# # [SimpleTransformerLMHead] Initializing...
# 2022-05-17 01:36:47.863296: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-17 01:36:47.890550: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-17 01:36:47.890702: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-17 01:36:47.891422: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# ...

# %%
lm_model.train()
# Out:
# # [SimpleTransformerLMHead] Training...
# # Model Dir: logs/model
#  - History Path: logs/model/history.csv
#  - Checkpoint Path: logs/model/checkpoints.h5
#  - TB Path: logs/model
# Epoch 1/20
#       1/Unknown - 2s 2s/step - loss: 9.8256 - simple_transformer_loss: 9.8256
# 2022-05-17 01:36:55.672122: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 21/21 [==============================] - 5s 154ms/step - loss: 7.1950 - simple_transformer_loss: 7.1950
# Epoch 2/20
# 20/21 [===========================>..] - ETA: 0s - loss: 2.4396 - simple_transformer_loss: 2.4396

# %%
lm_model.save()

# %%
generated_txt = lm_model.generate("i will always be", 50)
print(generated_txt)
