# %%
#@formatter:off
# %load_ext autoreload
# %autoreload 2
#@formatter:on
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.Config import Config
from src.SimpleTransformerLMHead import SimpleTransformerLMHead

# %%
config = Config(
    {
        "VOCAB_SZ": 30000,
        "MAX_LEN": 100,
        "ATT_HEADS": 2,
        "DIM_EMB": 100,
        "DIM_FFN": 2048,
        "WARMUP_STEPS": 10000,
    },
    {
        "BATCH_SIZE": 32,
        "EPOCHS": 1,
        "DATASET": ["data/wiki2.train.tokens"]
    })
# "DATASET": ["data/wiki2.train.tokens"]
# "DATASET": ["data/wiki2.train.raw"]
# "DATASET": ["data/beatles.txt"]

# %%
lm_model = SimpleTransformerLMHead().new(config)
# Out:
# # [SimpleTransformerLMHead] Initializing...
# # [SimpleTransformerLMHead] Creating new model...
# [DATASET]: Loading ['data/beatles.txt']
# [TOKENIZER]: Initializing...
# # [SimpleTransformerLMHead] Vocabulary size: 2499
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 100)]             0
#
#  simple_transformer_3 (Simpl  ((None, 100, 2500),      1005348
#  eTransformer)                (None, 100, 100))
#
# =================================================================
# Total params: 1,005,348
# Trainable params: 1,005,348
# Non-trainable params: 0
# _________________________________________________________________

# %%
lm_model.train('Cicely Mary Barker was a')
# Out:
# # [SimpleTransformerLMHead] Training...
# # Model Dir: logs/model_1
#  - History Path: logs/model_1/history.csv
#  - Checkpoint Path: logs/model_1/checkpoints.h5
#  - TB Path: logs/model_1
#     160/Unknown - 3s 10ms/step - loss: 7.4680 - simple_transformer_3_loss: 7.4680[START] cicely mary barker was a
# Generated 101 tokens
#
# # GREEDY GENERATED:
# [START] [UNK] mary [UNK] was a
#
# [START] cicely mary barker was a
# Generated 101 tokens
#
# # RANDOM GENERATED:
# [START] [UNK] mary [UNK] was a fixing krishna turing deep shy sees lady jealous thought sigh roll butterflies biggest fiddle threw juniors chachachachancebirthday meaning <UNK> saloon war tides scrimp yellow return greetings majesty turing isle struggled denied jukebox songs continuing peaked bounder seen tres beautiful look noones l sour aunt evrybody hold begins shelter piggies port biggest mmmmmmmmmmmmmmmm noise been car lightning seat play write writer corporation shall sweet most funtake warning however walrus travelling tight mighty fair everyday more could plat jai tangerine lines shine funny equipped nay  standin g natural little meter ruin beside brings chain hearted highheel was wet h make overtime meant
#
# [START] cicely mary barker was a
# Generated 101 tokens
#
# # TOP_K GENERATED:
# [START] [UNK] mary [UNK] was a hair belong turn madam over wait rival hunting sees inside wish friend yeht band theres cummin tearing madly changed sweeter somehow fed both away maxwell book goo windy box board legend l  revival happy chip suitcase learned lives meander travelled phone shout ba wings shows makes letters da clutching meman world feet standin hat return searching bed laughs neighborhood meaning farm sack liebt thin paramucho care few is change quando cold perform pleasure plays note clean gibraltar nimmst seven velvet am gone wonders thirtyone phone comes restless closing nur u soooo goodbyes filled made lend und mood of suddenly es
#
# [START] cicely mary barker was a
# Generated 101 tokens
#
# # TOP_P GENERATED:
# [START] [UNK] mary [UNK] was a showdown threw gun moments forever broke jonah cares yard knees bottle ginger drink forgive cried pillow clowns only nanananaaa sundays kissing nothin make deinen mad correct tears light yes kann laughs sexy kave quit most maid , summersets direction seance rob whoah windy meander ran telling cave rock alright inciting parlour therewith trolly higher sie tuesdays winging voice summer blows arms tries feed change tucson forgotten silently temperatures sdaeh wait melody blue daya licks wakes flowers weeds ground yea misunderstood higher ready leaves joke winging inquire mmm fool strawberry um pass goodbye finds insecure crazy chairman haze jar ought haired six
#
# 162/162 [==============================] - 18s 105ms/step - loss: 7.4551 - simple_transformer_3_loss: 7.4551

# %%
lm_model.save()
# Out:
# # [SimpleTransformerLMHead] Saving model to model_save...
# WARNING:absl:Found untraced functions such as token_and_position_embedding_3_layer_call_fn, token_and_position_embedding_3_layer_call_and_return_conditional_losses, transformer_block_3_layer_call_fn, transformer_block_3_layer_call_and_return_conditional_losses, dense_11_layer_call_fn while saving (showing 5 of 32). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model_save/assets
# INFO:tensorflow:Assets written to: model_save/assets

# %%
generated_txt = lm_model.generate("i will always be", 200)
print(generated_txt)
# Out:
# # [SimpleTransformerLMHead] Generating...
# [START] i will always be
# Generated 201 tokens
# [START] i will always be makes percetly runs verzeiht round burst house police somebody appreciate wood alright self listening many keep did chip clown for putting gain wasting youa poe institution rehearsal piece this won military oscar turnstyle holiday loser travling owned roses speaking daya , a machine didnt mending hugs goodbye coral freely mots feelin store bits screen owned brand thing meetyeah few weeks amore mundo chain tied mama melody insecure comrade misunderstood tchaikovsky frantic both next died peoplewho d modern rehearsal kindly shed wild everybodys life shoes slow disease musst cuts flowers wisdom jonah textpert woos stop splendid under wie upon habit filled perfectly wring rehearsal polythene jo fbi resign yeeeeh gestern appreciate thankful mir spinning christ hari quietly fancy sent thankful dylans carathon upstairs sdaeh edih cent waltz return uptown stupid shook tears key kite edison lil already cos meaningless twofoot stop shown changes novel mayayake greet octopuss escaping touched busy dylans chance telling his metaphysical held waiting tune oclock one maxwell small corporation working [START] things helping paul my line yeht priestess love drifting top within choking yeeeeh sleeping  gibraltar cannot some done paramucho shelter jewellers ties customer cake will same knowing [START] chip dead hill jo closer fifty hunting same

# %%
load_lm_model = SimpleTransformerLMHead().load("model_save")
# Out:
# # [SimpleTransformerLMHead] Initializing...
# # [SimpleTransformerLMHead] Loading model from model_save...

# %%
load_lm_model.generate("i will always be", 200)
# Out:
# # [SimpleTransformerLMHead] Generating...
# [START] i will always be
# Generated 201 tokens
# '[START] i will always be perfectly playing loner sundays count waiting possessions poe can dripping foolin hearted cia whole evolution mattered fine dressing sweaty earth bound winter creme dancer tea boys show styes ran prove real radiate laughing moon somewhere and drift evryone paperback doubt dug sdaeh he blow complainin grandchildren except gone meander cellophane darling holy things denied dovetail dirty aaahhh succeed him boat field point arriving died knife wouldnt cut finally face questo arise lifting stay goodlooking rope yourselfthen lil cottage knickers an stick unpleasant again eye calling killerdiller trouble prospects kind wipe dark creme disagree clue painting year bien care postcard seance lighten health get wives fed care delay fifty little middle brew mean owww naturally zapped saturday fell ihr people fixing going junior starched gee most sack cries cool oo , ducked impression goodbyes up college voices bringing ono full count messrs fragrant ol pretty somehow fly schemes threw loner knee buys penny sooooo eating destruction winter satisfaction foolish gin am pounds radiate dinner buy hula rent taxis r eggmen pouring port point rather who knowing anything roses worldif meeting those blows act negotiations diamonds desmond heba shadow silent suitcase needs invitation ol verstehen crash leaving splendid spend das curse starched dear'
